# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
list1 = [3,7,8,9,12]
plt.plot(list1)
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.plot(x,y)
plt.show()

# %%
fig, axis1 = plt.subplots()
fig = plt.figure(figsize=(12,6))

axis1.plot(x,y)
axis1.set_xlabel('X')
axis1.set_ylabel('Y')
plt.show()

# %%
x = np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
fig, axis2 = plt.subplots()
fig = plt.figure(figsize=(12,6))

axis2.plot(x, x**2)
plt.show()

# %%
fig, ax = plt.subplots()
plt.scatter(x, np.exp(x))

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %%
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   $4,000
# 1   Honda    Red          87899      4   $5,000
# 2  Toyota   Blue          32549      3   $7,000
# 3     BMW  Black          11179      5  $22,000
# 4  Nissan  White         213095      4   $3,500
# 5  Toyota  Green          99213      4   $4,500
# 6   Honda   Blue          45698      4   $7,500
# 7   Honda   Blue          54738      4   $7,000
# 8  Toyota  White          60000      4   $6,250
# 9  Nissan  White          31600      4   $9,700

# %%
plt.plot(car_sales['Price'])

# %%
plt.plot(car_sales['Odometer (KM)'])

# %%
# Both plots worked

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[\$\,]", "")
# Out:
# <ipython-input-30-546042c79b2b>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace("[\$\,]", "")

# %%
car_sales["Price"] = car_sales["Price"].astype('int64')
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 528.0+ bytes

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales["Sale Date"] = pd.date_range("2/9/2022", periods=len(car_sales))

# %%
plt.plot(car_sales['Price'], car_sales['Total Sales'])
plt.show()

# %%
plt.scatter(car_sales["Odometer (KM)"],car_sales["Price"] )
plt.title("Odometer vs Price scatter plot plot")
plt.xlabel('Odometer (KM)')
plt.ylabel('Price')
plt.show()

# %%
plt.bar(car_sales["Make"], car_sales["Odometer (KM)"])
plt.title("Make vs Odometer bar plot")
plt.xlabel('Make')
plt.ylabel('Odometer (KM)')
plt.show()

# %%
plt.hist(car_sales["Make"])
plt.title('Histogram of car make')
plt.xlabel("Make")
plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,figsize= (10,10))

ax1.plot(car_sales["Price"],car_sales["Total Sales"] )
ax1.set_title("Price vs total sales line plot")
ax1.set_xlabel('Price')
ax1.set_ylabel('Total Sales')
ax2.scatter(car_sales["Odometer (KM)"],car_sales["Price"] )
ax2.set_title("Odometer vs Price scatter plot plot")
ax2.set_xlabel('Odometer (KM)')
ax2.set_ylabel('Price')
ax3.bar(car_sales["Make"], car_sales["Odometer (KM)"])
ax3.set_title("Make vs Odometer bar plot")
ax3.set_xlabel('Make')
ax3.set_ylabel('Odometer (KM)')
ax4.hist(car_sales["Make"])
ax4.set_title('Histogram of car make')
ax4.set_xlabel("Make")
plt.show()
plt.savefig('matplotlib.jpg')

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors         Price   Total Sales
# count      10.000000  10.000000     10.000000     10.000000
# mean    78601.400000   4.000000   7645.000000  41170.000000
# std     61983.471735   0.471405   5379.407753  24739.141277
# min     11179.000000   3.000000   3500.000000   4000.000000
# 25%     35836.250000   4.000000   4625.000000  21500.000000
# 50%     57369.000000   4.000000   6625.000000  43750.000000
# 75%     96384.500000   4.000000   7375.000000  58750.000000
# max    213095.000000   5.000000  22000.000000  76450.000000

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  Sale Date
# 0  Toyota  White         150043      4   4000         4000 2022-02-09
# 1   Honda    Red          87899      4   5000         9000 2022-02-10
# 2  Toyota   Blue          32549      3   7000        16000 2022-02-11
# 3     BMW  Black          11179      5  22000        38000 2022-02-12
# 4  Nissan  White         213095      4   3500        41500 2022-02-13

# %%
import seaborn as sns

# %%
box_plot = sns.boxplot(x="Colour", y="Total Sales", data=car_sales)

# %%
lm_plot = sns.lmplot(x="Total Sales", y="Odometer (KM)", data=car_sales, height=5, hue='Make', ci=False )

# %%
pair_plot = sns.pairplot(car_sales, plot_kws={'color':'green'})

# %%
pc = car_sales[['Total Sales','Price','Odometer (KM)']].corr(method ='pearson')

cols = ['Total Sales','Price','Odometer (KM)']

ax = sns.heatmap(pc, annot=True,
                 yticklabels=cols,
                 xticklabels=cols,
                 annot_kws={'size': 20})
